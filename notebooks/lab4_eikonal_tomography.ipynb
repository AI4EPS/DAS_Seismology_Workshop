# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AI4EPS/DAS_Seismology_Workshop/blob/main/notebooks/lab4_eikonal_tomography.ipynb)
#
# # Lab 4: Eikonal Traveltime Tomography
#
# In this lab, you will learn how to:
# - Compute noise cross-correlations from DAS data
# - Combine noise correlations with earthquake arrivals
# - Perform high-resolution seismic tomography
#
# ---

# %%
# Lab content coming soon
