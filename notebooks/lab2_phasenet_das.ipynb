# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AI4EPS/DAS_Seismology_Workshop/blob/main/notebooks/lab2_phasenet_das.ipynb)
#
# # Lab 2: ML Phase Picking with PhaseNet-DAS
#
# In this lab, you will learn how to:
# - Apply PhaseNet-DAS for P/S phase picking on DAS data
# - Evaluate picking quality
# - Visualize phase arrivals
#
# ---

# %%
# Lab content coming soon
