# %% [markdown]
# ![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)
#
# # Lab 4: Eikonal Traveltime Tomography
#
# In this lab, you will learn how to:
# - Run a 2D example of Eikonal tomography using a synthetic case: [Open Notebook](lab4_eikonal_tomography_2d.ipynb)
# - Apply the same approach for a 3D Eikonal tomography test based on a field-data case from the Long Valley caldera: [Open Notebook](lab4_eikonal_tomography_3d.ipynb)
#
# You can click on the link to the notebooks to start working on them.
#
# ---
